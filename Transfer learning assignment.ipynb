# %%
import pandas as pd
import numpy as np
import os

import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from keras.applications import VGG19
import keras
from keras.models import Model
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Data Loading

# %%
train_dataset = "plant-seedlings-classification/train"
test_dataset = "plant-seedlings-classification/test"

image_size = 128
classes = 12

WIDTH = 128
HEIGHT = 128
DEPTH = 3
INPUT_SHAPE = (WIDTH, HEIGHT, DEPTH)

# %%
#Build train generator

image_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0
)

train_generator = image_datagenerator.flow_from_directory(train_dataset,
                                                    target_size=(image_size, image_size),
                                                    subset='training',
                                                    class_mode='categorical',
                                                    shuffle=True,
                                                    batch_size = 4750,
                                                    seed= 9)
X,Y = train_generator.next()
# Out:
# Found 4750 images belonging to 12 classes.

# %%
# Create test data set
class_mapping = { train_generator.class_indices[k]:k for k in train_generator.class_indices}

def create_test_dataset(test_images_dir, image_size, rescale = 1):
    filenames = []
    test_data = []
    
    for img_file in os.listdir(test_images_dir):
        filenames.append(img_file)

        img = tf.keras.preprocessing.image.load_img(test_images_dir + '/' + img_file)
        img_new = img.resize([image_size, image_size])
        img_array = tf.keras.preprocessing.image.img_to_array(img_new)
        if rescale is not 1:
            img_array = img_array * 1./255
        test_data.append(img_array)
    
    test_data = np.array(test_data,dtype=np.float32)
    
    return test_data, filenames 

test_data, filenames  = create_test_dataset(test_dataset,image_size, rescale = 1./255)

# %%
class_mapping
# Out:
# {0: 'Black-grass',
#  1: 'Charlock',
#  2: 'Cleavers',
#  3: 'Common Chickweed',
#  4: 'Common wheat',
#  5: 'Fat Hen',
#  6: 'Loose Silky-bent',
#  7: 'Maize',
#  8: 'Scentless Mayweed',
#  9: 'Shepherds Purse',
#  10: 'Small-flowered Cranesbill',
#  11: 'Sugar beet'}

# %%
#Prepare submisiion file
def prepare_submission(submission_file, model):
    predicted_class = []
    for img in test_data:
        img_instance = np.expand_dims(img, axis=0)
        img_instance_class = model.predict(img_instance)
        img_instance_class = np.argmax(img_instance_class,axis=1)
        img_instance_class = class_mapping.get(img_instance_class[0], np.nan)
        predicted_class.append(img_instance_class)
        pass

    results = pd.DataFrame({"file":filenames,"species":predicted_class})
    results.to_csv(submission_file, index = False)

# %%
#Cross validation
num_folds = 5

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=42)

kfold = KFold(n_splits=num_folds, random_state=1, shuffle=True)

# Merge inputs and targets
inputs = np.concatenate((x_train, x_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# %%
#Train the model
def train_model(no_epochs,batch_size, model):
    
    # Define per-fold score containers
    acc_score_per_fold = []

    # K-fold Cross Validation model evaluation
    fold_no = 1
    for train, test in kfold.split(inputs, targets):

        # Fit data to model
        history = model.fit(inputs[train], targets[train],
                      batch_size=batch_size,
                      epochs=no_epochs,
                      verbose=2)

        # Generate generalization metrics
        loss, accuracy = model.evaluate(inputs[test], targets[test], verbose=0)
        acc_score_per_fold.append(accuracy)

        print(f'> Fold {fold_no} Accuracy score: {accuracy}')
        # Increase fold number
        fold_no = fold_no + 1

    # == Provide average scores ==
    print('Average accuracy score for all folds:')
    print(f'> Accuracy score: {np.mean(acc_score_per_fold)} (+- {np.std(acc_score_per_fold)})')
    print('------------------------------------------------------------------------')

# %%
vgg_model = VGG19(weights='imagenet', input_shape=INPUT_SHAPE, include_top=False)
# Out:
# WARNING:tensorflow:From /home/dinesh/.local/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /home/dinesh/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# VGG19 Model summary
vgg_model.summary()
# Out:
# Model: "vgg19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 128, 128, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# =================================================================
# Total params: 20,024,384
# Trainable params: 20,024,384
# Non-trainable params: 0
# _________________________________________________________________

# %%
def setTrainableLayersVGG(vgg_model):
    for layer in vgg_model.layers:
        set_trainable = False
        if layer.name in ['block5_conv1', 'block5_conv2','block5_conv3', 'block5_conv4','block5_pool']: # add layer name which are needed to retrain
            set_trainable = True
            
        if set_trainable:
            layer.trainable = True
        else:
            layer.trainable = False
    return vgg_model

# %%
def create_transfer_model(fineTune,number_of_hidden_layers, optimizer, activation ):
    #Clear any previous model from memory
    tf.keras.backend.clear_session()
    
    tranfer_model = VGG19(weights='imagenet', input_shape=INPUT_SHAPE, include_top=False)

    if fineTune == True: # Configured layers will be opened to modify
        tranfer_model = setTrainableLayersVGG(tranfer_model) 
    else: # All layers will be frozen
        for layer in tranfer_model.layers:
            layer.trainable = False 


    output = tranfer_model.layers[-1].output
    output = keras.layers.Flatten()(output)
    trans_model = Model(tranfer_model.input, output)

    model = Sequential()
    model.add(trans_model)

    for i in range(0,number_of_hidden_layers):
            model.add(Dense(512))
            model.add(Activation(activation))
            model.add(Dropout(0.3))

    model.add(Dense(12, activation='softmax'))
    
    # Model summary
    model.summary()
    
    #Specify Loass and Optimizer
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# ## Create models with different configurations

# %%
# V4
model = create_transfer_model(fineTune=False,number_of_hidden_layers=0,optimizer='adam',activation='relu' )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Model)              (None, 8192)              20024384
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                98316
# =================================================================
# Total params: 20,122,700
# Trainable params: 98,316
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# V5
model = create_transfer_model(fineTune=True,number_of_hidden_layers=0,optimizer='adam',activation='relu' )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Model)              (None, 8192)              20024384
# _________________________________________________________________
# dense_1 (Dense)              (None, 12)                98316
# =================================================================
# Total params: 20,122,700
# Trainable params: 9,537,548
# Non-trainable params: 10,585,152
# _________________________________________________________________

# %%
# V6
model = create_transfer_model(fineTune=True,number_of_hidden_layers=1,optimizer='adam',activation='relu' )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model_1 (Model)              (None, 8192)              20024384
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               4194816
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 12)                6156
# =================================================================
# Total params: 24,225,356
# Trainable params: 13,640,204
# Non-trainable params: 10,585,152
# _________________________________________________________________

# %% [markdown]
# ## Train the model

# %%
train_model(10, 100, model) # V4
# Out:
# WARNING:tensorflow:From /home/dinesh/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/10
#  - 253s - loss: 2.1214 - accuracy: 0.2613
# Epoch 2/10
#  - 252s - loss: 1.5911 - accuracy: 0.4863
# Epoch 3/10
#  - 267s - loss: 1.3770 - accuracy: 0.5674
# Epoch 4/10
#  - 263s - loss: 1.2344 - accuracy: 0.6311
# Epoch 5/10
#  - 247s - loss: 1.1343 - accuracy: 0.6653
# Epoch 6/10
#  - 246s - loss: 1.0471 - accuracy: 0.6955
# Epoch 7/10
#  - 246s - loss: 0.9727 - accuracy: 0.7276
# Epoch 8/10
#  - 246s - loss: 0.9335 - accuracy: 0.7287
# Epoch 9/10
#  - 258s - loss: 0.8712 - accuracy: 0.7603
# Epoch 10/10
#  - 259s - loss: 0.8208 - accuracy: 0.7737
# > Fold 1 Accuracy score: 0.5736842155456543
# Epoch 1/10
#  - 256s - loss: 0.9020 - accuracy: 0.7400
# Epoch 2/10
#  - 256s - loss: 0.8349 - accuracy: 0.7663
# Epoch 3/10
#  - 249s - loss: 0.7940 - accuracy: 0.7800
# Epoch 4/10
#  - 258s - loss: 0.7357 - accuracy: 0.8039
# Epoch 5/10
#  - 270s - loss: 0.7094 - accuracy: 0.8118
# Epoch 6/10
#  - 252s - loss: 0.6809 - accuracy: 0.8192
# Epoch 7/10
#  - 250s - loss: 0.6500 - accuracy: 0.8311
# Epoch 8/10
#  - 251s - loss: 0.6388 - accuracy: 0.8311
# Epoch 9/10
#  - 249s - loss: 0.5979 - accuracy: 0.8474
# Epoch 10/10
#  - 249s - loss: 0.5790 - accuracy: 0.8497
# > Fold 2 Accuracy score: 0.7589473724365234
# Epoch 1/10
#  - 248s - loss: 0.6238 - accuracy: 0.8368
# Epoch 2/10
#  - 248s - loss: 0.5975 - accuracy: 0.8455
# Epoch 3/10
#  - 248s - loss: 0.5634 - accuracy: 0.8595
# Epoch 4/10
#  - 247s - loss: 0.5370 - accuracy: 0.8695
# Epoch 5/10
#  - 248s - loss: 0.5144 - accuracy: 0.8766
# Epoch 6/10
#  - 248s - loss: 0.5065 - accuracy: 0.8747
# Epoch 7/10
#  - 247s - loss: 0.4822 - accuracy: 0.8861
# Epoch 8/10
#  - 247s - loss: 0.4695 - accuracy: 0.8868
# Epoch 9/10
#  - 247s - loss: 0.4529 - accuracy: 0.8939
# Epoch 10/10
#  - 247s - loss: 0.4344 - accuracy: 0.8966
# > Fold 3 Accuracy score: 0.8315789699554443
# Epoch 1/10
#  - 247s - loss: 0.4713 - accuracy: 0.8863
# Epoch 2/10
#  - 250s - loss: 0.4472 - accuracy: 0.8982
# Epoch 3/10
#  - 247s - loss: 0.4401 - accuracy: 0.9011
# Epoch 4/10
#  - 247s - loss: 0.4323 - accuracy: 0.8982
# Epoch 5/10
#  - 247s - loss: 0.4143 - accuracy: 0.9037
# Epoch 6/10
#  - 247s - loss: 0.3984 - accuracy: 0.9097
# Epoch 7/10
#  - 247s - loss: 0.3890 - accuracy: 0.9111
# Epoch 8/10
#  - 247s - loss: 0.3761 - accuracy: 0.9208
# Epoch 9/10
#  - 245s - loss: 0.3659 - accuracy: 0.9232
# Epoch 10/10
#  - 245s - loss: 0.3584 - accuracy: 0.9229
# > Fold 4 Accuracy score: 0.8768420815467834
# Epoch 1/10
#  - 245s - loss: 0.3817 - accuracy: 0.9137
# Epoch 2/10
#  - 245s - loss: 0.3614 - accuracy: 0.9168
# Epoch 3/10
#  - 247s - loss: 0.3598 - accuracy: 0.9184
# Epoch 4/10
#  - 245s - loss: 0.3386 - accuracy: 0.9295
# Epoch 5/10
#  - 245s - loss: 0.3254 - accuracy: 0.9332
# Epoch 6/10
#  - 245s - loss: 0.3191 - accuracy: 0.9358
# Epoch 7/10
#  - 245s - loss: 0.3122 - accuracy: 0.9392
# Epoch 8/10
#  - 245s - loss: 0.3049 - accuracy: 0.9405
# Epoch 9/10
#  - 245s - loss: 0.2951 - accuracy: 0.9434
# Epoch 10/10
#  - 245s - loss: 0.2895 - accuracy: 0.9426
# > Fold 5 Accuracy score: 0.9021052718162537
# Average accuracy score for all folds:
# > Accuracy score: 0.7886315822601319 (+- 0.11797064998216382)
# ------------------------------------------------------------------------

# %%
train_model(10, 100, model) # V5
# Out:
# WARNING:tensorflow:From /home/dinesh/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/10
#  - 298s - loss: 2.5094 - accuracy: 0.1250
# Epoch 2/10
#  - 302s - loss: 2.3932 - accuracy: 0.1405
# Epoch 3/10
#  - 303s - loss: 2.3491 - accuracy: 0.1718
# Epoch 4/10
#  - 304s - loss: 2.2668 - accuracy: 0.1926
# Epoch 5/10
#  - 304s - loss: 1.9568 - accuracy: 0.2942
# Epoch 6/10
#  - 304s - loss: 1.6319 - accuracy: 0.3895
# Epoch 7/10
#  - 304s - loss: 1.3973 - accuracy: 0.4853
# Epoch 8/10
#  - 337s - loss: 1.1559 - accuracy: 0.5858
# Epoch 9/10
#  - 333s - loss: 0.9559 - accuracy: 0.6563
# Epoch 10/10
#  - 313s - loss: 0.7194 - accuracy: 0.7474
# > Fold 1 Accuracy score: 0.551578938961029
# Epoch 1/10
#  - 306s - loss: 0.7981 - accuracy: 0.7287
# Epoch 2/10
#  - 305s - loss: 0.5543 - accuracy: 0.8097
# Epoch 3/10
#  - 305s - loss: 0.4055 - accuracy: 0.8618
# Epoch 4/10
#  - 305s - loss: 0.3144 - accuracy: 0.8900
# Epoch 5/10
#  - 305s - loss: 0.2618 - accuracy: 0.9100
# Epoch 6/10
#  - 305s - loss: 0.1585 - accuracy: 0.9487
# Epoch 7/10
#  - 305s - loss: 0.1343 - accuracy: 0.9534
# Epoch 8/10
#  - 306s - loss: 0.1554 - accuracy: 0.9466
# Epoch 9/10
#  - 305s - loss: 0.1442 - accuracy: 0.9539
# Epoch 10/10
#  - 305s - loss: 0.0668 - accuracy: 0.9789
# > Fold 2 Accuracy score: 0.7884210348129272
# Epoch 1/10
#  - 305s - loss: 0.3182 - accuracy: 0.9063
# Epoch 2/10
#  - 305s - loss: 0.1706 - accuracy: 0.9442
# Epoch 3/10
#  - 305s - loss: 0.0689 - accuracy: 0.9792
# Epoch 4/10
#  - 305s - loss: 0.0480 - accuracy: 0.9845
# Epoch 5/10
#  - 305s - loss: 0.0429 - accuracy: 0.9871
# Epoch 6/10
#  - 305s - loss: 0.0344 - accuracy: 0.9918
# Epoch 7/10
#  - 305s - loss: 0.0362 - accuracy: 0.9884
# Epoch 8/10
#  - 305s - loss: 0.0646 - accuracy: 0.9771
# Epoch 9/10
#  - 305s - loss: 0.1117 - accuracy: 0.9616
# Epoch 10/10
#  - 305s - loss: 0.0557 - accuracy: 0.9808
# > Fold 3 Accuracy score: 0.9231578707695007
# Epoch 1/10
#  - 305s - loss: 0.1108 - accuracy: 0.9645
# Epoch 2/10
#  - 305s - loss: 0.0737 - accuracy: 0.9763
# Epoch 3/10
#  - 305s - loss: 0.0914 - accuracy: 0.9721
# Epoch 4/10
#  - 305s - loss: 0.0498 - accuracy: 0.9842
# Epoch 5/10
#  - 305s - loss: 0.0356 - accuracy: 0.9863
# Epoch 6/10
#  - 305s - loss: 0.0638 - accuracy: 0.9821
# Epoch 7/10
#  - 305s - loss: 0.0351 - accuracy: 0.9903
# Epoch 8/10
#  - 305s - loss: 0.0210 - accuracy: 0.9945
# Epoch 9/10
#  - 306s - loss: 0.0263 - accuracy: 0.9921
# Epoch 10/10
#  - 305s - loss: 0.0277 - accuracy: 0.9903
# > Fold 4 Accuracy score: 0.975789487361908
# Epoch 1/10
#  - 305s - loss: 0.0774 - accuracy: 0.9763
# Epoch 2/10
#  - 305s - loss: 0.1082 - accuracy: 0.9679
# Epoch 3/10
#  - 305s - loss: 0.0528 - accuracy: 0.9834
# Epoch 4/10
#  - 305s - loss: 0.0132 - accuracy: 0.9950
# Epoch 5/10
#  - 306s - loss: 0.0061 - accuracy: 0.9979
# Epoch 6/10
#  - 343s - loss: 0.0025 - accuracy: 0.9992
# Epoch 7/10
#  - 329s - loss: 6.3603e-04 - accuracy: 1.0000
# Epoch 8/10
#  - 319s - loss: 2.0756e-04 - accuracy: 1.0000
# Epoch 9/10
#  - 306s - loss: 1.4203e-04 - accuracy: 1.0000
# Epoch 10/10
#  - 307s - loss: 1.1633e-04 - accuracy: 1.0000
# > Fold 5 Accuracy score: 0.9957894682884216
# Average accuracy score for all folds:
# > Accuracy score: 0.8469473600387574 (+- 0.16445676867893905)
# ------------------------------------------------------------------------

# %%
train_model(10, 100, model) # V6
# Out:
# Epoch 1/10
#  - 309s - loss: 2.6976 - accuracy: 0.1155
# Epoch 2/10
#  - 305s - loss: 2.4973 - accuracy: 0.1205
# Epoch 3/10
#  - 305s - loss: 2.4793 - accuracy: 0.1324
# Epoch 4/10
#  - 306s - loss: 2.4242 - accuracy: 0.1429
# Epoch 5/10
#  - 307s - loss: 2.4150 - accuracy: 0.1429
# Epoch 6/10
#  - 307s - loss: 2.4137 - accuracy: 0.1426
# Epoch 7/10
#  - 306s - loss: 2.4121 - accuracy: 0.1421
# Epoch 8/10
#  - 306s - loss: 2.4139 - accuracy: 0.1429
# Epoch 9/10
#  - 306s - loss: 2.4138 - accuracy: 0.1426
# Epoch 10/10
#  - 306s - loss: 2.4133 - accuracy: 0.1416
# > Fold 1 Accuracy score: 0.1168421059846878
# Epoch 1/10
#  - 306s - loss: 2.4149 - accuracy: 0.1342
# Epoch 2/10
#  - 306s - loss: 2.4163 - accuracy: 0.1342
# Epoch 3/10
#  - 306s - loss: 2.4156 - accuracy: 0.1363
# Epoch 4/10
#  - 306s - loss: 2.4145 - accuracy: 0.1295
# Epoch 5/10
#  - 306s - loss: 2.4151 - accuracy: 0.1361
# Epoch 6/10
#  - 307s - loss: 2.4155 - accuracy: 0.1321
# Epoch 7/10
#  - 307s - loss: 2.4151 - accuracy: 0.1305
# Epoch 8/10
#  - 307s - loss: 2.4145 - accuracy: 0.1324
# Epoch 9/10
#  - 308s - loss: 2.4148 - accuracy: 0.1326
# Epoch 10/10
#  - 320s - loss: 2.4149 - accuracy: 0.1324
# > Fold 2 Accuracy score: 0.1473684161901474
# Epoch 1/10
#  - 308s - loss: 2.4198 - accuracy: 0.1379
# Epoch 2/10
#  - 308s - loss: 2.4196 - accuracy: 0.1329
# Epoch 3/10
#  - 309s - loss: 2.4200 - accuracy: 0.1345
# Epoch 4/10
#  - 308s - loss: 2.4202 - accuracy: 0.1337
# Epoch 5/10
#  - 309s - loss: 2.4201 - accuracy: 0.1339
# Epoch 6/10
#  - 308s - loss: 2.4202 - accuracy: 0.1358
# Epoch 7/10
#  - 308s - loss: 2.4211 - accuracy: 0.1355
# Epoch 8/10
#  - 306s - loss: 2.4198 - accuracy: 0.1350
# Epoch 9/10
#  - 313s - loss: 2.4206 - accuracy: 0.1282
# Epoch 10/10
#  - 316s - loss: 2.4195 - accuracy: 0.1353
# > Fold 3 Accuracy score: 0.148421049118042
# Epoch 1/10
#  - 337s - loss: 2.4190 - accuracy: 0.1297
# Epoch 2/10
#  - 330s - loss: 2.4179 - accuracy: 0.1361
# Epoch 3/10
#  - 312s - loss: 2.4182 - accuracy: 0.1339
# Epoch 4/10
#  - 308s - loss: 2.4173 - accuracy: 0.1339
# Epoch 5/10
#  - 306s - loss: 2.4179 - accuracy: 0.1392
# Epoch 6/10
#  - 306s - loss: 2.4176 - accuracy: 0.1311
# Epoch 7/10
#  - 306s - loss: 2.4188 - accuracy: 0.1300
# Epoch 8/10
#  - 306s - loss: 2.4188 - accuracy: 0.1376
# Epoch 9/10
#  - 306s - loss: 2.4177 - accuracy: 0.1353
# Epoch 10/10
#  - 306s - loss: 2.4190 - accuracy: 0.1345
# > Fold 4 Accuracy score: 0.1473684161901474
# Epoch 1/10
#  - 306s - loss: 2.4151 - accuracy: 0.1371
# Epoch 2/10
#  - 327s - loss: 2.4151 - accuracy: 0.1397
# Epoch 3/10
#  - 334s - loss: 2.4145 - accuracy: 0.1389
# Epoch 4/10
#  - 345s - loss: 2.4158 - accuracy: 0.1397
# Epoch 5/10
#  - 384s - loss: 2.4151 - accuracy: 0.1389
# Epoch 6/10
#  - 358s - loss: 2.4157 - accuracy: 0.1395
# Epoch 7/10
#  - 310s - loss: 2.4157 - accuracy: 0.1400
# Epoch 8/10
#  - 308s - loss: 2.4151 - accuracy: 0.1397
# Epoch 9/10
#  - 307s - loss: 2.4155 - accuracy: 0.1392
# Epoch 10/10
#  - 307s - loss: 2.4152 - accuracy: 0.1397
# > Fold 5 Accuracy score: 0.12842105329036713
# Average accuracy score for all folds:
# > Accuracy score: 0.13768420815467836 (+- 0.012830017812346071)
# ------------------------------------------------------------------------

# %% [markdown]
# ## Prepare the submission

# %%
prepare_submission("submissions/tl_submission_v3.csv", model)

# %%
# V4 - Accuracy score: 0.7886315822601319 (+- 0.11797064998216382)
# V5 - Accuracy score: 0.8469473600387574 (+- 0.16445676867893905)
# V6 - Accuracy score: 0.13768420815467836 (+- 0.012830017812346071)
